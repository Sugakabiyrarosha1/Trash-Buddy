# %% [markdown]
# # 🗑️ Trash-Buddy Ensemble Methods
#
# ## Overview
# This notebook handles the ninth step of the Trash-Buddy pipeline: **Ensemble Methods**. We combine multiple models to improve performance:
#
# - Combine multiple models (voting, stacking)
# - Model averaging
# - Test-time augmentation
# - Cross-validation ensemble
#
# ---
#
# ## 📊 Prerequisites
#
# From previous steps, we have:
# - **Multiple trained models** (from Step 3 or Step 8)
# - **Test dataset** for evaluation (from Step 2)
# - **Individual model predictions** and performance metrics
#
# ---
#
# ## 🎯 Objectives
# 1. Load multiple trained models
# 2. Implement voting ensemble (hard/soft voting)
# 3. Implement stacking ensemble
# 4. Apply test-time augmentation
# 5. Compare ensemble performance with individual models
# 6. Select best ensemble strategy
